# %% [markdown]
# #**Theoretical Questions:**

# %% [markdown]
# #1. What is a random variable in probability theory?
#  - In probability theory, a random variable is a numerical value assigned to the outcome of a random experiment. Simply put, it provides a way to map the results of an unpredictable event (like flipping a coin or rolling a dice) into numbers that we can analyze mathematically.

# %% [markdown]
# #2. What are the types of random variables?
#  - There are two main types of random variables:
#
# 1. Discrete Random Variable: Takes on a countable set of values, such as the outcome of a dice roll (1, 2, 3, 4, 5, 6).
#
# 2. Continuous Random Variable: Can take on any value within a continuous range, like the temperature or the height of people in a population.

# %% [markdown]
# #3. What is the difference between discrete and continuous distributions?
#  - Difference between **discrete** and **continous distributions**.
#
# 1. **Discrete Distributions:**
#    - It deals with countable outcomes(whole numbers).
#    - Probabilities are assigned to individual values. for example, the probability of rolling a specific number on a die.
#    - Common examples: **Binomal distribution**, **Poisson distribution**.
#
# 2. **Continous Distributions:**
#    - It deals with uncountable outcomes(real number in a range).
#    - Probabilities are assigned to intervals, not individual values. for example, the probability of a person's height falling between 150 cm and 160 cm.
#    - Common examples: **Normal distribution**, **Exponential distribution**.

# %% [markdown]
# #4. What are probability distribution functions (PDF)?
#  - In probability theory, a probability distribution function (PDF) describes the likelihood of a random variable taking on specific values.
#
# **For discrete random variables:**
# The PDF is often referred to as a probability mass function (PMF). It assigns probabilities to individual values. For example, rolling a die: the PMF gives the probability of rolling any specific number (1 through 6).
#
# **For continuous random variables:**
# The PDF represents the probability density over a range of values. Instead of giving probabilities for exact values (which is 0 for continuous variables), it tells us how "dense" the probabilities are in a region. For example, in a normal distribution, the PDF is a bell-shaped curve.

# %% [markdown]
# #5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#  - Difference between cumulative distribution functions (CDF) and probability distribution functions (PDF).
#
# 1. **Probability Distribution Function (PDF):**
#    - The PDF describes the probability density of a random variable at a particular point or over a small interval.
#
#    - For discrete variables, this is the Probability Mass Function (PMF), which directly gives the probability of specific outcomes.
#
#    - For continuous variables, the PDF gives a curve; probabilities are found by calculating the area under the curve over a specific range.
#
# 2. **Cumulative Distribution Function (CDF):**
#   - The CDF shows the cumulative probability up to a particular value.
#
#   - It represents the probability that a random variable is less than or equal to a given value (𝑃(𝑋≤𝑥)).
#
#   - The CDF is a non-decreasing function and always ranges from 0 to 1.

# %% [markdown]
# #6. What is a discrete uniform distribution?
#  - A Discrete Uniform Distribution is a probability distribution where a finite number of outcomes are equally likely.

# %% [markdown]
# #7. What are the key properties of a Bernoulli distribution?
#  - The key properties of a Bernoulli distribution are:-
#    - Probability Mass Function (PMF):-
#      -  P(X = x) = {P, 1-p, if x = 1, if x = 0}
#   - Mean (Expected Value):-
#      - E[X]=p
#   - Variance:-
#      - Var(X)=p(1-p)
#   - Moment-Generating Function (MGF):-

# %% [markdown]
# #8. What is the binomial distribution, and how is it used in probability?
#  - The binomial distribution models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success.
#  - Probability Mass Function (PMF):- - The probability of getting exactly k successes in n trials.

# %% [markdown]
# #9. What is the Poisson distribution and where is it applied?
#  - The Poisson distribution models the probability of a certain number of events occurring in a fixed interval of time or space, given that these events happen at a constant average rate and independently of each other.
#  - 𝜆 (lambda) = expected number of events per unit time/space.
#  - X = actual number of events occurring.

# %% [markdown]
# # 10.What is a continuous uniform distribution?
#  - He continuous uniform distribution is a probability distribution where all values in a given range are equally likely to occur. It is also known as the rectangular distribution.

# %% [markdown]
# #11. What are the characteristics of a normal distribution?
#  - The characteristics of normal distrubution are:
#   - Bell-Shaped & Symmetric:-
#     - The distribution is perfectly symmetrical about the mean.
#   - Mean = Median = Mode:-
#     - Since it is symmetric, all three central tendency measures are equal.
#   - Spread Determined by 𝜎:-
#     - Smaller σ → Narrower, taller curve (less variability).
#   - otal Area Under the Curve = 1
#     - The total probability of all possible values sums to 1.

# %% [markdown]
# #12. What is the standard normal distribution, and why is it important?
#  - The standard normal distribution is a special case of the normal distribution with:
#   - Mean 𝜇 = 0 μ=0
#  - Standard Normal Distribution is Important because:-
#   - Many real-world variables follow a normal distribution with different means and standard deviations.
#   - Converting them to a standard normal distribution allows us to use a single table for probability lookups.

# %% [markdown]
# #13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#  - The Central Limit Theorem (CLT) states that, regardless of the original population distribution, the sampling distribution of the sample mean will tend to be normal if the sample size is sufficiently large.
#  - Allows Use of Normal Distribution for Inferential Statistics Even if the population is not normal, sample means will follow a normal distribution for large n.

# %% [markdown]
# #14. How does the Central Limit Theorem relate to the normal distribution?
#  - The Central Limit Theorem (CLT) is directly linked to the normal distribution because it explains why normality appears so frequently in statistics.
#  - The CLT states that the distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the shape of the original population distribution.
#  - If we compute the mean of each sample and plot the distribution of these means, it will approximate a normal distribution as n increases.

# %% [markdown]
# #15. What is the application of Z statistics in hypothesis testing?
#  - Z-statistics (or Z-tests) are used in hypothesis testing when the population standard deviation (σ) is known and the sample size is sufficiently large (𝑛 ≥ 30 n≥30).

# %% [markdown]
# #16. How do you calculate a Z-score, and what does it represent?
#  - Z = 185-170 / 10 = 15 / 10 = 1.5
#  - Interpretation: - A Z-score of 1.5 means that 185 cm is 1.5 standard deviations above the mean. - 𝑍 = 0 Z=0 → The value is equal to the mean. - 𝑍 > 0 Z>0 → The value is above the mean. - 𝑍 < 0 Z <0 → The value is below the mean. - 𝑍 = 1 Z=1 → 1 standard deviation above the mean. - 𝑍 − 2 Z=− 2 → 2 standard deviations below the mean.

# %% [markdown]
# #17. What are point estimates and interval estimates in statistics ?
#  - point estimates:-
#   - Single value estimate
#   - Less accurate, no margin of error.
#   - Quick estimate
#   - Example: X = 168 cm
#  - interval estimates:
#   - Range of values
#   - More accurate, accounts for uncertainty.
#   - Better for decision-making.
#   - Example: (166.82,169.18).

# %% [markdown]
# #18. What is the significance of confidence intervals in statistical analysis?
#  - Confidence intervals (CIs) are essential in statistics because they provide a range of values that likely contains the true population parameter, rather than just a single estimate. This allows for better decision-making by accounting for uncertainty and variability in data.

# %% [markdown]
# #19. What is the relationship between a Z-score and a confidence interval?
#  - A Z-score and a confidence interval (CI) are closely related because the Z-score determines how wide the confidence interval is. The Z-score (or critical value, 𝑍 𝛼 / 2 Z α/2) corresponds to the probability of a given confidence level in a standard normal distribution.

# %% [markdown]
# #20. How are Z-scores used to compare different distributions?
#  - A Z-score standardizes data from different distributions, allowing for fair comparisons. It measures how many standard deviations a value is from the mean, making it useful for comparing values from different datasets with different means and standard deviations.

# %% [markdown]
# #21. What are the assumptions for applying the Central Limit Theorem?
#  - The Central Limit Theorem (CLT) states that, given a sufficiently large sample size, the sampling distribution of the sample mean will be approximately normal, regardless of the shape of the original population distribution. However, certain assumptions must be met for CLT to hold effectively.

# %% [markdown]
# #22. What is the concept of expected value in a probability distribution?
#  - The expected value (EV) of a probability distribution represents the long-run average outcome of a random variable over many trials. It provides a measure of the central tendency of the distribution.

# %% [markdown]
# #23. How does a probability distribution relate to the expected outcome of a random variable?
#  - A probability distribution describes how likely different outcomes of a random variable are. The expected value (EV) is the long-term average outcome based on that distribution. It provides a measure of the center of the distribution.

# %% [markdown]
# #**Practical Questions:**

# %% [markdown]
# #1. Write a Python program to generate a random variable and display its value.

# %%
import random

random_variable = random.randint(1, 100)
print("Generated Random Variable:", random_variable)
# Out:
# Generated Random Variable: 28

# %% [markdown]
# #2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 10
x = np.arange(1, n + 1)
pmf = np.ones(n) / n

plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution - PMF')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    """
    Calculates the PDF of a Bernoulli distribution.

    Parameters:
    x (int): The outcome (0 or 1).
    p (float): The probability of success (value of 1), 0 <= p <= 1.

    Returns:
    float: Probability of the outcome.
    """
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1.")
    if not (0 <= p <= 1):
        raise ValueError("p must be in the range [0, 1].")

    return p if x == 1 else 1 - p

p_success = 0.7
outcome = 1
probability = bernoulli_pdf(outcome, p_success)
print(f"The probability of outcome {outcome} is {probability}.")
# Out:
# The probability of outcome 1 is 0.7.

# %% [markdown]
# #4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
num_simulations = 1000

data = np.random.binomial(n, p, num_simulations)

plt.hist(data, bins=np.arange(0, n + 2) - 0.5, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Number of successes')
plt.ylabel('Frequency (normalized)')
plt.title('Binomial Distribution Histogram')
plt.xticks(range(0, n + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

lambda_value = 5
num_points = 1000

data = np.random.poisson(lambda_value, num_points)

plt.hist(data, bins=np.arange(0, max(data) + 2) - 0.5, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Number of Events')
plt.ylabel('Frequency (normalized)')
plt.title(f'Poisson Distribution (λ = {lambda_value})')
plt.xticks(range(0, max(data) + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
x = np.arange(1, n + 1)
pmf = np.ones(n) / n
cdf = np.cumsum(pmf)

plt.plot(x, cdf, marker='o', linestyle='-', color='green', label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) - Discrete Uniform Distribution')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# #7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

lower_bound = 0
upper_bound = 1
num_samples = 1000

data = np.random.uniform(lower_bound, upper_bound, num_samples)

plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 0
std_dev = 1
num_samples = 1000

data = np.random.normal(mean, std_dev, num_samples)

plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Normal Distribution Histogram (mean = {mean}, std = {std_dev})')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """
    Calculate Z-scores for a given dataset.

    Parameters:
    data (list or numpy array): The dataset.

    Returns:
    numpy array: Z-scores of the dataset.
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores

data = np.random.normal(10, 2, 100)
z_scores = calculate_z_scores(data)

plt.scatter(range(len(z_scores)), z_scores, color='purple', alpha=0.7, label='Z-scores')
plt.axhline(0, color='red', linestyle='--', label='Mean (Z=0)')
plt.xlabel('Data Index')
plt.ylabel('Z-score')
plt.title('Z-scores Visualization')
plt.legend()
plt.grid(alpha=0.6)
plt.show()

# %% [markdown]
# #10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_size = 1000
population = np.random.uniform(1, 10, sample_size)

num_samples = 500
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, 30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Demonstration of Central Limit Theorem')
plt.grid(alpha=0.6)
plt.show()

# %% [markdown]
# #11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 5
std_dev = 2
population_size = 10000
sample_size = 30
num_samples = 1000

population = np.random.normal(mean, std_dev, population_size)

sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(population, bins=30, color='skyblue', edgecolor='black', density=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Original Population Distribution')

plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='green', edgecolor='black', density=True)
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Distribution of Sample Means (CLT)')

plt.tight_layout()
plt.show()

# %% [markdown]
# #12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt

def standard_normal_distribution():
    """
    Calculates and plots the standard normal distribution (mean = 0, std = 1).
    """
    x = np.linspace(-4, 4, 500)
    mean = 0
    std = 1

    pdf = (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std) ** 2)

    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')
    plt.fill_between(x, pdf, color='skyblue', alpha=0.4)
    plt.xlabel('Value (Z)')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (mean = 0, std = 1)')
    plt.grid(alpha=0.6)
    plt.legend()
    plt.show()

standard_normal_distribution()

# %% [markdown]
# #13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np

def binomial_distribution(n, p, num_trials):
    """
    Simulates random variables using binomial distribution and calculates their probabilities.

    Parameters:
    n (int): Number of trials.
    p (float): Probability of success (0 <= p <= 1).
    num_trials (int): Number of random variables to generate.

    Returns:
    dict: A dictionary with outcomes and their probabilities.
    """

    data = np.random.binomial(n, p, num_trials)

    unique_outcomes, counts = np.unique(data, return_counts=True)
    probabilities = counts / num_trials

    distribution = dict(zip(unique_outcomes, probabilities))

    return distribution

n = 10
p = 0.5
num_trials = 1000

distribution = binomial_distribution(n, p, num_trials)

print("Binomial Distribution:")
for outcome, probability in distribution.items():
    print(f"Outcome: {outcome}, Probability: {probability:.4f}")
# Out:
# Binomial Distribution:
# Outcome: 0, Probability: 0.0010
# Outcome: 1, Probability: 0.0090
# Outcome: 2, Probability: 0.0430
# Outcome: 3, Probability: 0.1270
# Outcome: 4, Probability: 0.1850
# Outcome: 5, Probability: 0.2550
# Outcome: 6, Probability: 0.2050
# Outcome: 7, Probability: 0.1090
# Outcome: 8, Probability: 0.0490
# Outcome: 9, Probability: 0.0170

# %% [markdown]
# #14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def calculate_z_score(value, mean, std_dev):
    """
    Calculate the Z-score for a given data point.

    Parameters:
    value (float): The data point
    mean (float): The mean of the dataset
    std_dev (float): The standard deviation of the dataset

    Returns:
    float: Z-score of the data point
    """
    return (value - mean) / std_dev

data_point = 185
mean = 170
std_dev = 10

z_score = calculate_z_score(data_point, mean, std_dev)
print(f"Z-score of the data point ({data_point}): {z_score:.2f}")

x = np.linspace(-4, 4, 500)
pdf = stats.norm.pdf(x, 0, 1)

plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')
plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.fill_between(x, pdf, where=(x <= z_score), color='skyblue', alpha=0.4, label='Cumulative Area')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.title('Z-score Comparison with Standard Normal Distribution')
plt.legend()
plt.grid(alpha=0.6)
plt.show()
# Out:
# Z-score of the data point (185): 1.50

# %% [markdown]
# #15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
import scipy.stats as stats

def z_test(sample, mu_0, alpha):
    """
    Perform a Z-test for a sample to test the null hypothesis.

    Parameters:
    sample (list or numpy array): The sample data.
    mu_0 (float): The hypothesized population mean (null hypothesis).
    alpha (float): The significance level (e.g., 0.05 for 95% confidence).

    Returns:
    None: Prints the test results.
    """

    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    n = len(sample)

    z_stat = (sample_mean - mu_0) / (sample_std / np.sqrt(n))

    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_stat:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Reject the null hypothesis (H0) at α = {alpha}.")
    else:
        print(f"Fail to reject the null hypothesis (H0) at α = {alpha}.")

np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)
mu_0 = 55
alpha = 0.05

z_test(sample_data, mu_0, alpha)
# Out:
# Sample Mean: 48.12
# Z-statistic: -4.19
# P-value: 0.0000
# Reject the null hypothesis (H0) at α = 0.05.

# %% [markdown]
# #16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a dataset.

    Parameters:
    data (list or numpy array): The dataset.
    confidence (float): The confidence level (default is 95%).

    Returns:
    tuple: Lower and upper bounds of the confidence interval.
    """
    mean = np.mean(data)
    std_error = stats.sem(data)
    margin_of_error = stats.t.ppf((1 + confidence) / 2, len(data) - 1) * std_error
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return lower_bound, upper_bound

np.random.seed(42)
data = np.random.normal(50, 10, 100)

confidence_level = 0.95
lower, upper = calculate_confidence_interval(data, confidence_level)
print(f"{confidence_level*100}% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95.0% Confidence Interval: (47.16, 50.76)

# %% [markdown]
# #17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for the mean of the dataset.

    Parameters:
    data (list or numpy array): The dataset.
    confidence (float): The confidence level (default is 95%).

    Returns:
    tuple: Lower and upper bounds of the confidence interval.
    """
    mean = np.mean(data)
    std_error = stats.sem(data)
    margin_of_error = stats.t.ppf((1 + confidence) / 2, len(data) - 1) * std_error
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return mean, lower_bound, upper_bound

np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=50)

mean, lower, upper = calculate_confidence_interval(data)
print(f"Mean of the dataset: {mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# Mean of the dataset: 96.62
# 95% Confidence Interval: (92.64, 100.60)

# %% [markdown]
# #18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

mean = 0
std_dev = 1

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 500)
pdf = stats.norm.pdf(x, mean, std_dev)

plt.plot(x, pdf, color='blue', label=f'Normal Distribution\n(mean = {mean}, std = {std_dev})')
plt.fill_between(x, pdf, color='skyblue', alpha=0.4)
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Probability Density Function of a Normal Distribution')
plt.grid(alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# #19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

lambda_value = 4

x = np.arange(0, 15)

cdf = stats.poisson.cdf(x, mu=lambda_value)

print("Poisson Distribution CDF:")
for value, prob in zip(x, cdf):
    print(f"P(X ≤ {value}) = {prob:.4f}")

plt.step(x, cdf, where="post", label=f'Poisson CDF (λ = {lambda_value})', color='blue')
plt.xlabel('Number of Events')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function of Poisson Distribution')
plt.grid(alpha=0.7)
plt.legend()
plt.show()
# Out:
# Poisson Distribution CDF:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# #20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

lower_bound = 0
upper_bound = 10
num_samples = 1000

random_variables = np.random.uniform(lower_bound, upper_bound, num_samples)

expected_value = (lower_bound + upper_bound) / 2

sample_mean = np.mean(random_variables)

print(f"Theoretical Expected Value: {expected_value:.2f}")
print(f"Sample Mean (Approximation): {sample_mean:.2f}")
# Out:
# Theoretical Expected Value: 5.00
# Sample Mean (Approximation): 4.97

# %% [markdown]
# #21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
data1 = np.random.normal(loc=50, scale=10, size=100)
data2 = np.random.normal(loc=60, scale=15, size=100)

std_dev1 = np.std(data1, ddof=1)
std_dev2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

datasets = ['Dataset 1', 'Dataset 2']
std_devs = [std_dev1, std_dev2]

plt.bar(datasets, std_devs, color=['blue', 'green'], alpha=0.7, edgecolor='black')
plt.ylabel('Standard Deviation')
plt.title('Comparison of Standard Deviations')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 9.08
# Standard Deviation of Dataset 2: 14.31

# %% [markdown]
# #22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=50)

data_range = np.max(data) - np.min(data)

q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 57.18
# Interquartile Range (IQR): 17.96

# %% [markdown]
# #23. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    """
    Normalize the dataset using Z-score normalization.

    Parameters:
    data (numpy array): Input dataset.

    Returns:
    numpy array: Normalized dataset (Z-scores).
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores

np.random.seed(42)
data = np.random.normal(loc=100, scale=20, size=100)

normalized_data = z_score_normalization(data)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='green', alpha=0.7, edgecolor='black')
plt.title('Z-score Normalized Data Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
import scipy.stats as stats

def calculate_skewness_kurtosis(data):
    """
    Calculate skewness and kurtosis for a given dataset.

    Parameters:
    data (list or numpy array): The dataset.

    Returns:
    tuple: Skewness and Kurtosis values.
    """
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data)
    return skewness, kurtosis

np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=500)

skewness, kurtosis = calculate_skewness_kurtosis(data)
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurtosis:.4f}")
# Out:
# Skewness: 0.1796
# Kurtosis: 0.2564
